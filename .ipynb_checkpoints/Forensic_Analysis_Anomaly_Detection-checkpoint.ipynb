# %% [markdown]
# # Unsupervised Anomaly Detection in Time Series of Bank Transactions

# %% [markdown]
# ## 1. Importing Modules

# %%
# Data and Stats Packages
import pandas as pd
import numpy as np
import re
import datetime as dt

# Visualization Packages
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# Anomaly Detection Packages
from sklearn import preprocessing
from sklearn.ensemble import IsolationForest
from sklearn.svm import OneClassSVM
from sklearn.covariance import EllipticEnvelope
from statsmodels.tsa.seasonal import seasonal_decompose


import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 2. Data Cleaning & Exploratory Data Analysis

# %%
bank = pd.read_excel('Sample_bank_transaction_data.xlsx')
bank_raw = df.copy()

# %%
bank.head()
# Out:
#       Account No       DATE               TRANSACTION DETAILS  CHQ.NO.  \
# 0  409000611074' 2017-06-29  TRF FROM  Indiaforensic SERVICES      NaN
# 1  409000611074' 2017-07-05  TRF FROM  Indiaforensic SERVICES      NaN
# 2  409000611074' 2017-07-18        FDRL/INTERNAL FUND TRANSFE      NaN
# 3  409000611074' 2017-08-01   TRF FRM  Indiaforensic SERVICES      NaN
# 4  409000611074' 2017-08-16        FDRL/INTERNAL FUND TRANSFE      NaN
#
#   VALUE DATE  WITHDRAWAL AMT  DEPOSIT AMT  BALANCE AMT  .
# 0 2017-06-29             NaN    1000000.0    1000000.0  .
# 1 2017-07-05             NaN    1000000.0    2000000.0  .
# 2 2017-07-18             NaN     500000.0    2500000.0  .
# 3 2017-08-01             NaN    3000000.0    5500000.0  .
# 4 2017-08-16             NaN     500000.0    6000000.0  .

# %%
bank.shape
# Out:
# (116201, 9)

# %%
bank.describe()
# Out:
#              CHQ.NO.  WITHDRAWAL AMT   DEPOSIT AMT   BALANCE AMT
# count     905.000000    5.354900e+04  6.265200e+04  1.162010e+05
# mean   791614.503867    4.489190e+06  3.806586e+06 -1.404852e+09
# std    151205.932910    1.084850e+07  8.683093e+06  5.348202e+08
# min         1.000000    1.000000e-02  1.000000e-02 -2.045201e+09
# 25%    704231.000000    3.000000e+03  9.900000e+04 -1.690383e+09
# 50%    873812.000000    4.708300e+04  4.265000e+05 -1.661395e+09
# 75%    874167.000000    5.000000e+06  4.746411e+06 -1.236888e+09
# max    874525.000000    4.594475e+08  5.448000e+08  8.500000e+06

# %%
bank.columns
# Out:
# Index(['Account No', 'DATE', 'TRANSACTION DETAILS', 'CHQ.NO.', 'VALUE DATE',
#        'WITHDRAWAL AMT', 'DEPOSIT AMT', 'BALANCE AMT', '.'],
#       dtype='object')

# %%
bank.rename(columns={'Account No': 'account_no', 'DATE':'date', 'TRANSACTION DETAILS':'details', 'CHQ.NO.':'chq_no', 'VALUE DATE':'value_date',
       'WITHDRAWAL AMT':'withdrawal_amt', 'DEPOSIT AMT':'deposit_amt', 'BALANCE AMT':'balance_amt'}, inplace=True)
bank.head(3)
# Out:
#       account_no       date                           details  chq_no  \
# 0  409000611074' 2017-06-29  TRF FROM  Indiaforensic SERVICES     NaN
# 1  409000611074' 2017-07-05  TRF FROM  Indiaforensic SERVICES     NaN
# 2  409000611074' 2017-07-18        FDRL/INTERNAL FUND TRANSFE     NaN
#
#   value_date  withdrawal_amt  deposit_amt  balance_amt  .
# 0 2017-06-29             NaN    1000000.0    1000000.0  .
# 1 2017-07-05             NaN    1000000.0    2000000.0  .
# 2 2017-07-18             NaN     500000.0    2500000.0  .

# %% [markdown]
# We have a time series data without anomaly labeling. Let's take a closer look at the features.

# %%
def first_look(df, col):
    """
    Enables a quick search for characteristics of a column in a data frame.
    
    df: Data Frame
    col: Column of interest
    
    """
    val = pd.DataFrame(df[col].value_counts(dropna=False))
    val = val.assign(percent=(df[col].value_counts(dropna=False, normalize=True).values)*100)
    info = pd.DataFrame({'Column_Name': [col],'Null_Rows': [df[col].isna().sum()], 'Column_Type': [df[col].dtypes]}, index=['column_info'])
    return info, val

# %% [markdown]
# ### i. account_no

# %%
info , val = first_look(bank, bank.columns[0])

# %%
info
# Out:
#             Column_Name  Null_Rows Column_Type
# column_info  account_no          0      object

# %%
val
# Out:
#                account_no    percent
# 1196428'            48779  41.978124
# 409000362497'       29840  25.679641
# 409000438620'       13454  11.578214
# 1196711'            10536   9.067048
# 409000493210'        6014   5.175515
# 409000438611'        4588   3.948331
# 409000611074'        1093   0.940612
# 409000493201'        1044   0.898443
# 409000425051'         802   0.690183
# 409000405747'          51   0.043889

# %% [markdown]
# Since **account_no** is a unique indicator of customers (in our case we have 10 customers who have rather unbalanced transaction frequencies), we should keep the data type as string and for future investigation purposes we will remove the **'** (last character).

# %%
bank['account_no'] = bank.account_no.str.extract(r'(\d+)\'')

# %%
plt.figure(figsize=(10,6))
plt.xticks(rotation=45)
fig = sns.countplot(data=bank, x='account_no', order=bank.account_no.value_counts().index)
fig2 = fig.twinx()

fig.yaxis.set_label_position('left')
fig2.yaxis.set_label_position('right')

fig2.set_ylabel('% of total')

for p in fig.patches:
    x=p.get_bbox().get_points()[:,0]
    y=p.get_bbox().get_points()[1,1]
    fig.annotate('{:.2f}%'.format(100.*y/len(bank)), (x.mean(), y), 
            ha='center', va='bottom') # set the alignment of the text
fig2.grid(None)
fig2.set_ylim(0,100)
fig2.grid()
plt.show()

# %% [markdown]
# ### ii. date

# %%
info , val = first_look(bank, bank.columns[1])

# %%
info
# Out:
#             Column_Name  Null_Rows     Column_Type
# column_info        date          0  datetime64[ns]

# %%
bank.date.apply(lambda x: x.year).value_counts()
# Out:
# 2018    35534
# 2016    30372
# 2017    29113
# 2015    15658
# 2019     5524
# Name: date, dtype: int64

# %%
((bank.date).dt.dayofweek).value_counts()
# Out:
# 0    22662
# 4    22058
# 1    21561
# 3    20446
# 2    19421
# 5     9830
# 6      223
# Name: date, dtype: int64

# %%
conditions = [((bank.date).dt.dayofweek  > 4), ((bank.date).dt.dayofweek  < 5)]
values = [1, 0]
bank['weekend_date'] = np.select(conditions, values)

# %% [markdown]
# ### iii. details

# %%
info , val = first_look(bank, bank.columns[2])

# %%
info
# Out:
#             Column_Name  Null_Rows Column_Type
# column_info     details       2499      object

# %%
bank[bank.details.isna()].account_no.value_counts()
# Out:
# 409000362497    2484
# 1196711           15
# Name: account_no, dtype: int64

# %%
bank[bank.details.isna()].date.apply(lambda x: x.year).value_counts()
# Out:
# 2015    1259
# 2016    1240
# Name: date, dtype: int64

# %%
bank.details.sample(10)
# Out:
# 104211    Indiaforensic SERVICES INDIA PVT
# 85747           FDRL/INTERNAL FUND TRANSFE
# 106690           KRYPTOS MOBILE PRIVATE LI
# 57026                         632208051874
# 63471           FDRL/INTERNAL FUND TRANSFE
# 48413                     CASHDEP/GURGAON/
# 63130           FDRL/INTERNAL FUND TRANSFE
# 86216           FDRL/INTERNAL FUND TRANSFE
# 98907      TRF FROM Indiaforensic SERVICES
# 115523          FDRL/INTERNAL FUND TRANSFE
# Name: details, dtype: object

# %% [markdown]
# This function has the potential to provide information about anomalies. It could help us find new features. For starters, let's define a column that indicates whether a transaction has no proper details value (Null or nonsense values).

# %%
conditions = [(bank.details.isna()), (bank.details.str.extract(r'(\w+)')[0].isna())]
values = [.5, .25]
bank['details_penalty'] = np.select(conditions, values)

# %%
bank.details_penalty.value_counts()
# Out:
# 0.00    112050
# 0.50      2499
# 0.25      1652
# Name: details_penalty, dtype: int64

# %% [markdown]
# This penalty is not a red flag by itself, but can be an additional checkpoint for the anomaly detection results. Let's leave the **details** column at this point and move on to the next feature.

# %% [markdown]
# ### iv. chq_no

# %%
info , val = first_look(bank, bank.columns[3])

# %%
info
# Out:
#             Column_Name  Null_Rows Column_Type
# column_info      chq_no     115296     float64

# %%
val
# Out:
#           chq_no    percent
# NaN       115296  99.221177
# 3.0            3   0.002582
# 2.0            3   0.002582
# 4.0            3   0.002582
# 5.0            3   0.002582
# ...          ...        ...
# 874018.0       1   0.000861
# 874017.0       1   0.000861
# 874015.0       1   0.000861
# 874014.0       1   0.000861
# 873820.0       1   0.000861
#
# [895 rows x 2 columns]

# %%
bank[bank.chq_no<10]
# Out:
#          account_no       date                           details  chq_no  \
# 2907   409000425051 2017-06-12  Indiaforensic SERVICES INDIA PVT     1.0
# 2908   409000425051 2017-06-12  Indiaforensic SERVICES I P LTD F     2.0
# 2909   409000425051 2017-06-12  Indiaforensic SERVICES I P LTD P     5.0
# 2910   409000425051 2017-06-12  Indiaforensic SERVICES INDIA PVT     6.0
# 2911   409000425051 2017-06-12  Indiaforensic SERVICES I P LTD R     4.0
# 2912   409000425051 2017-06-12  Indiaforensic SERVICES I P LTD R     3.0
# 2913   409000425051 2017-06-14  Indiaforensic SERVICES INDIA PVT     9.0
# 2914   409000425051 2017-06-14  Indiaforensic SERVICES INDIA PVT     7.0
# 2915   409000425051 2017-06-14  Indiaforensic SERVICES INDIA PVT     8.0
# 5654   409000438611 2018-06-25   NEFT/000041992898/Indiaforensic     2.0
# 5967   409000438611 2018-08-13   NEFT/000046766266/Indiaforensic     3.0
# 6227   409000438611 2018-09-21   NEFT/000050794506/Indiaforensic     4.0
# 6229   409000438611 2018-09-21   NEFT/000050794647/Indiaforensic     5.0
# 22174  409000438620 2018-06-25      RTGS/YESBH18176501898/Indfor     1.0
# 22176  409000438620 2018-06-25      RTGS/YESBH18176502779/Indfor     3.0
# 22178  409000438620 2018-06-25      RTGS/YESBH18176503243/Indfor     2.0
# 22208  409000438620 2018-06-26      RTGS/YESBH18177599358/Indfor     5.0
# 22210  409000438620 2018-06-26      RTGS/YESBH18177600906/Indfor     4.0
# 22220  409000438620 2018-06-27      RTGS/YESBH18178695745/Indfor     8.0
# 22247  409000438620 2018-06-28      RTGS/YESBH18179801622/Indfor     9.0
#
#       value_date  withdrawal_amt  deposit_amt   balance_amt  .  \
# 2907  2017-06-12           200.0          NaN  6.010878e+05  .
# 2908  2017-06-12           200.0          NaN  6.008878e+05  .
# 2909  2017-06-12           200.0          NaN  6.006878e+05  .
# 2910  2017-06-12           200.0          NaN  6.004878e+05  .
# 2911  2017-06-12           200.0          NaN  6.002878e+05  .
# 2912  2017-06-12           200.0          NaN  6.000878e+05  .
# 2913  2017-06-14           200.0          NaN  5.998878e+05  .
# 2914  2017-06-14           200.0          NaN  5.996878e+05  .
# 2915  2017-06-14           200.0          NaN  5.994878e+05  .
# 5654  2018-06-25       5000000.0          NaN -5.325215e+08  .
# 5967  2018-08-13      15000000.0          NaN -5.442627e+08  .
# 6227  2018-09-21      10000000.0          NaN -5.422974e+08  .
# 6229  2018-09-21       5000000.0          NaN -5.472974e+08  .
# 22174 2018-06-25      15000000.0          NaN -5.162501e+08  .
# 22176 2018-06-25      15000000.0          NaN -5.312501e+08  .
# 22178 2018-06-25      15000000.0          NaN -5.462502e+08  .
# 22208 2018-06-26       3900000.0          NaN -5.312436e+08  .
# 22210 2018-06-26      15000000.0          NaN -5.462436e+08  .
# 22220 2018-06-27      10000000.0          NaN -5.462546e+08  .
# 22247 2018-06-28      15000000.0          NaN -5.462736e+08  .
#
#        details_penalty
# 2907               0.0
# 2908               0.0
# 2909               0.0
# 2910               0.0
# 2911               0.0
# 2912               0.0
# 2913               0.0
# 2914               0.0
# 2915               0.0
# 5654               0.0
# 5967               0.0
# 6227               0.0
# 6229               0.0
# 22174              0.0
# 22176              0.0
# 22178              0.0
# 22208              0.0
# 22210              0.0
# 22220              0.0
# 22247              0.0

# %%
bank[~bank.chq_no.isna()].sample(10)
# Out:
#       account_no       date                          details    chq_no  \
# 34403    1196711 2016-06-24         VODAFONE MOBILE SERVICES  874337.0
# 32989    1196711 2016-04-04        NATIONAL INSURANCE CO LTD  874303.0
# 67091    1196428 2017-10-18         NEFT/000023886003/BHARTI  704180.0
# 32761    1196711 2016-03-18                   RAI ASSOCIATES  874174.0
# 33415    1196711 2016-04-25                             MTNL  874325.0
# 33992    1196711 2016-05-30                BHARTI AIRTEL LTD  874203.0
# 32991    1196711 2016-04-04        NATIONAL INSURANCE CO LTD  874310.0
# 32895    1196711 2016-03-30                     ROHIT BANSAL  874161.0
# 28759    1196711 2015-09-04             Tata Teleservice Ltd  873639.0
# 57556    1196428 2016-12-02  NEFT/000011194091/Indiaforensic  704172.0
#
#       value_date  withdrawal_amt  deposit_amt   balance_amt  .  \
# 34403 2016-06-24        22050.00          NaN -1.768164e+09  .
# 32989 2016-04-04         5725.00          NaN -1.282325e+09  .
# 67091 2017-10-18      4950000.00          NaN -1.687030e+09  .
# 32761 2016-03-18        42075.00          NaN -1.558024e+09  .
# 33415 2016-04-25         1740.00          NaN -1.530677e+09  .
# 33992 2016-05-30          286.00          NaN -1.759610e+09  .
# 32991 2016-04-04         2953.00          NaN -1.282332e+09  .
# 32895 2016-03-30       114338.44          NaN -1.451573e+09  .
# 28759 2015-09-04         1053.00          NaN -1.195082e+09  .
# 57556 2016-12-02      9238400.00          NaN -1.627676e+09  .
#
#        details_penalty  cheque_penalty
# 34403              0.0               0
# 32989              0.0               0
# 67091              0.0               0
# 32761              0.0               0
# 33415              0.0               0
# 33992              0.0               0
# 32991              0.0               0
# 32895              0.0               0
# 28759              0.0               0
# 57556              0.0               0

# %%
bank[bank.chq_no<100000].tail()
# Out:
#          account_no       date                           details  chq_no  \
# 22220  409000438620 2018-06-27      RTGS/YESBH18178695745/Indfor     8.0
# 22245  409000438620 2018-06-28      RTGS/YESBH18179801413/Indfor    10.0
# 22247  409000438620 2018-06-28      RTGS/YESBH18179801622/Indfor     9.0
# 37589       1196428 2015-01-02      RTGS/YESBH15002745737/Indfor  4549.0
# 37593       1196428 2015-01-03  FUND TRF TO  Indiaforensic SERVI  4550.0
#
#       value_date  withdrawal_amt  deposit_amt   balance_amt  .  \
# 22220 2018-06-27      10000000.0          NaN -5.462546e+08  .
# 22245 2018-06-28       1900000.0          NaN -5.312736e+08  .
# 22247 2018-06-28      15000000.0          NaN -5.462736e+08  .
# 37589 2015-01-02       5500000.0          NaN -1.590326e+09  .
# 37593 2015-01-03       2200000.0          NaN -1.590153e+09  .
#
#        details_penalty  cheque_penalty
# 22220              0.0               1
# 22245              0.0               0
# 22247              0.0               1
# 37589              0.0               0
# 37593              0.0               0

# %%
bank['cheque_penalty'] = np.where(bank.chq_no<11, 1, 0)

# %%
bank.cheque_penalty.value_counts()
# Out:
# 0    116180
# 1        21
# Name: cheque_penalty, dtype: int64

# %% [markdown]
# Again, this penalty is not a red flag in itself, but on the other hand, given the incorrect check numbers, it can be an additional check point for the anomaly detection results. Let's leave the **chq_no** column at this point and move on to the next feature.

# %% [markdown]
# ### v. value_date

# %%
info , val = first_look(bank, bank.columns[4])

# %%
info
# Out:
#             Column_Name  Null_Rows     Column_Type
# column_info  value_date          0  datetime64[ns]

# %%
bank['day_diff'] = ((bank.date - bank.value_date) / np.timedelta64(1,'D')).astype(int)

# %%
bank.day_diff.value_counts()
# Out:
#  0     116066
#  1         86
#  3         15
#  2         11
#  5          9
#  4          8
#  29         2
# -1          1
#  18         1
#  8          1
#  6          1
# Name: day_diff, dtype: int64

# %%
bank[(bank.day_diff < 0) | (bank.day_diff > 5)]
# Out:
#           account_no       date                    details  chq_no value_date  \
# 63340        1196428 2017-05-16  FT ZL1705177BD415D1 SHREE     NaN 2017-05-17
# 63717        1196428 2017-06-06  Payments For : 9090000405     NaN 2017-05-31
# 103332  409000362497 2017-04-05  REPAYMENT CREDIT [7090021     NaN 2017-03-07
# 103335  409000362497 2017-04-05  Sweep Trf To: 40900036427     NaN 2017-03-07
# 104111  409000362497 2017-05-05  FD BOOKING 365 DAYS  DEPO     NaN 2017-04-27
# 112081  409000362497 2018-04-27  Sweep Trf To: 40900036427     NaN 2018-04-09
#
#         withdrawal_amt  deposit_amt   balance_amt  .  details_penalty  \
# 63340              NaN     50000.00 -1.657087e+09  .              0.0
# 63717        657534.00          NaN -1.689498e+09  .              0.0
# 103332             NaN   4812379.15 -1.831388e+09  .              0.0
# 103335      7952045.15          NaN -1.842516e+09  .              0.0
# 104111     58500000.00          NaN -1.902886e+09  .              0.0
# 112081      9176351.00          NaN -1.886386e+09  .              0.0
#
#         cheque_penalty  day_diff
# 63340                0        -1
# 63717                0         6
# 103332               0        29
# 103335               0        29
# 104111               0         8
# 112081               0        18

# %% [markdown]
# As one could obviously see, we have obtained an important feature that we will look at more closely in the anomaly analysis. Let's have a quick look whether we have weekend value_dates.

# %%
((bank.value_date).dt.dayofweek  > 4).value_counts()
# Out:
# False    106146
# True      10055
# Name: value_date, dtype: int64

# %%
conditions = [((bank.value_date).dt.dayofweek  > 4), ((bank.value_date).dt.dayofweek  < 5)]
values = [1, 0]
bank['weekend_value_date'] = np.select(conditions, values)

# %% [markdown]
# ### vi. withdrawal_amt

# %%
info , val = first_look(bank, bank.columns[5])

# %%
info
# Out:
#                 Column_Name  Null_Rows Column_Type
# column_info  withdrawal_amt      62652     float64

# %%
bank.withdrawal_amt.describe()
# Out:
# count    5.354900e+04
# mean     4.489190e+06
# std      1.084850e+07
# min      1.000000e-02
# 25%      3.000000e+03
# 50%      4.708300e+04
# 75%      5.000000e+06
# max      4.594475e+08
# Name: withdrawal_amt, dtype: float64

# %%
bank[~bank.withdrawal_amt.isna()].count()
# Out:
# account_no         53549
# date               53549
# details            53549
# chq_no               905
# value_date         53549
# withdrawal_amt     53549
# deposit_amt            0
# balance_amt        53549
# .                  53549
# details_penalty    53549
# cheque_penalty     53549
# day_diff           53549
# dtype: int64

# %%
bank[bank.withdrawal_amt.isna()].count()
# Out:
# account_no         62652
# date               62652
# details            60153
# chq_no                 0
# value_date         62652
# withdrawal_amt         0
# deposit_amt        62652
# balance_amt        62652
# .                  62652
# details_penalty    62652
# cheque_penalty     62652
# day_diff           62652
# dtype: int64

# %%
pd.DataFrame(bank.groupby('account_no').withdrawal_amt.count()).sort_values('withdrawal_amt', ascending=False)
# Out:
#               withdrawal_amt
# account_no
# 1196428                16687
# 409000362497           15477
# 409000438620            8391
# 409000493210            5227
# 1196711                 5025
# 409000438611            1333
# 409000611074             778
# 409000493201             575
# 409000405747              28
# 409000425051              28

# %%
conditions = [((bank.balance_amt+bank.withdrawal_amt)==0), ((bank.balance_amt+bank.withdrawal_amt)!=0)]
values = [0, 100*(bank.withdrawal_amt/(bank.balance_amt+bank.withdrawal_amt))]
bank['withdrawal_over_balance'] = np.select(conditions, values)

# %%
bank['withdrawal_amt'] = bank.withdrawal_amt.fillna(0)

# %%
bank['withdrawal_over_balance'] = bank.withdrawal_over_balance.fillna(0)

# %%
bank[bank.withdrawal_amt!=0].head()
# Out:
#       account_no       date                           details  chq_no  \
# 10  409000611074 2017-08-16  INDO GIBL Indiaforensic STL01071     NaN
# 11  409000611074 2017-08-16  INDO GIBL Indiaforensic STL02071     NaN
# 12  409000611074 2017-08-16  INDO GIBL Indiaforensic STL03071     NaN
# 13  409000611074 2017-08-16  INDO GIBL Indiaforensic STL04071     NaN
# 14  409000611074 2017-08-16  INDO GIBL Indiaforensic STL05071     NaN
#
#    value_date  withdrawal_amt  deposit_amt  balance_amt  .  details_penalty  \
# 10 2017-08-16        133900.0          0.0    8366100.0  .              0.0
# 11 2017-08-16         18000.0          0.0    8348100.0  .              0.0
# 12 2017-08-16          5000.0          0.0    8343100.0  .              0.0
# 13 2017-08-16        195800.0          0.0    8147300.0  .              0.0
# 14 2017-08-16         81600.0          0.0    8065700.0  .              0.0
#
#     cheque_penalty  day_diff  deposit_over_balance  withdrawal_over_balance
# 10               0         0                   NaN                 1.575294
# 11               0         0                   NaN                 0.215154
# 12               0         0                   NaN                 0.059894
# 13               0         0                   NaN                 2.346849
# 14               0         0                   NaN                 1.001559

# %% [markdown]
# ### vii. deposit_amt

# %%
info , val = first_look(bank, bank.columns[6])

# %%
info
# Out:
#              Column_Name  Null_Rows Column_Type
# column_info  deposit_amt      53549     float64

# %%
bank.deposit_amt.describe()
# Out:
# count    6.265200e+04
# mean     3.806586e+06
# std      8.683093e+06
# min      1.000000e-02
# 25%      9.900000e+04
# 50%      4.265000e+05
# 75%      4.746411e+06
# max      5.448000e+08
# Name: deposit_amt, dtype: float64

# %%
bank[~bank.deposit_amt.isna()].count()
# Out:
# account_no         62652
# date               62652
# details            60153
# chq_no                 0
# value_date         62652
# withdrawal_amt         0
# deposit_amt        62652
# balance_amt        62652
# .                  62652
# details_penalty    62652
# cheque_penalty     62652
# day_diff           62652
# dtype: int64

# %%
bank[bank.deposit_amt.isna()].count()
# Out:
# account_no         53549
# date               53549
# details            53549
# chq_no               905
# value_date         53549
# withdrawal_amt     53549
# deposit_amt            0
# balance_amt        53549
# .                  53549
# details_penalty    53549
# cheque_penalty     53549
# day_diff           53549
# dtype: int64

# %%
pd.DataFrame(bank.groupby('account_no').deposit_amt.count()).sort_values('deposit_amt', ascending=False)
# Out:
#               deposit_amt
# account_no
# 1196428             32092
# 409000362497        14363
# 1196711              5511
# 409000438620         5063
# 409000438611         3255
# 409000493210          787
# 409000425051          774
# 409000493201          469
# 409000611074          315
# 409000405747           23

# %%
bank[bank.deposit_amt.isna() & bank.withdrawal_amt.isna()].count()
# Out:
# account_no         0
# date               0
# details            0
# chq_no             0
# value_date         0
# withdrawal_amt     0
# deposit_amt        0
# balance_amt        0
# .                  0
# details_penalty    0
# cheque_penalty     0
# day_diff           0
# dtype: int64

# %%
conditions = [((bank.balance_amt-bank.deposit_amt)==0), ((bank.balance_amt-bank.deposit_amt)!=0)]
values = [0, 100*(bank.deposit_amt/(bank.balance_amt-bank.deposit_amt))]
bank['deposit_over_balance'] = np.select(conditions, values)
bank['deposit_over_balance'] = bank.deposit_over_balance.fillna(0)

# %%
bank['deposit_amt'] = bank.deposit_amt.fillna(0)

# %%
# Out:
#           account_no       date                           details  chq_no  \
# 71147        1196428 2018-02-12        FDRL/NATIONAL ELECTRONIC F     NaN
# 66814        1196428 2017-10-10                      728311870532     NaN
# 65534        1196428 2017-09-06        FDRL/INTERNAL FUND TRANSFE     NaN
# 41606        1196428 2015-10-03  DSB CASH PICKP Indiaforensic MET     NaN
# 34615        1196711 2016-07-15      NEFT/AXISF16197004247/Indfor     NaN
# 99535   409000362497 2016-11-22          NOMISMA MOBILE SOLUTIONS     NaN
# 42883        1196428 2015-11-20                  CASHDEP/RAJOURI/     NaN
# 1369    409000493201 2017-08-04        FDRL/INTERNAL FUND TRANSFE     NaN
# 103568  409000362497 2017-04-13         FUTURE RETAIL LIMITED (OW     NaN
# 70579        1196428 2018-01-23         NEFT/N023180458543380/PAY     NaN
# 42555        1196428 2015-11-10                   CASHDEP/BOISAR/     NaN
# 61383        1196428 2017-03-06                    CASHDEP/DAMAN/     NaN
# 61054        1196428 2017-02-24                 CASHDEP/SILVASSA/     NaN
# 102545  409000362497 2017-03-09      RTGS/SBINH17068041048/Indfor     NaN
# 98176   409000362497 2016-10-04      RTGS/SBINH16278196689/Indfor     NaN
# 106181  409000362497 2017-08-04         PASFAR TECHNOLOGIES PRIVA     NaN
# 112603  409000362497 2018-05-21                     IMPS 2105184C     NaN
# 103949  409000362497 2017-04-28        FDRL/INTERNAL FUND TRANSFE     NaN
# 110302  409000362497 2018-01-10        FDRL/INTERNAL FUND TRANSFE     NaN
# 58769        1196428 2016-12-31        FDRL/INTERNAL FUND TRANSFE     NaN
#
#        value_date  withdrawal_amt  deposit_amt   balance_amt  .  \
# 71147  2018-02-12        11950.00         0.00 -1.672162e+09  .
# 66814  2017-10-10            0.00    150000.00 -1.685208e+09  .
# 65534  2017-09-06      5000000.00         0.00 -1.671714e+09  .
# 41606  2015-10-03            0.00   2000000.00 -1.581073e+09  .
# 34615  2016-07-15            0.00   1000000.00 -1.743352e+09  .
# 99535  2016-11-22         1150.00         0.00 -1.807307e+09  .
# 42883  2015-11-20            0.00    867600.00 -1.665041e+09  .
# 1369   2017-08-04            0.00     50000.00  1.559823e+06  .
# 103568 2017-04-13        13732.00         0.00 -1.839974e+09  .
# 70579  2018-01-23            0.00   1314170.22 -1.676496e+09  .
# 42555  2015-11-10            0.00      5100.00 -1.677555e+09  .
# 61383  2017-03-06            0.00     18800.00 -1.684138e+09  .
# 61054  2017-02-24            0.00      5000.00 -1.680764e+09  .
# 102545 2017-03-09            0.00  14900000.00 -1.912247e+09  .
# 98176  2016-10-04            0.00   8000000.00 -1.797472e+09  .
# 106181 2017-08-04         5876.00         0.00 -1.934323e+09  .
# 112603 2018-05-21      3127143.84         0.00 -1.897927e+09  .
# 103949 2017-04-28            0.00   9000000.00 -1.914313e+09  .
# 110302 2018-01-10            0.00   5000000.00 -1.915942e+09  .
# 58769  2016-12-31     15000000.00         0.00 -1.584370e+09  .
#
#         details_penalty  cheque_penalty  day_diff  deposit_over_balance  \
# 71147              0.00               0         0             -0.000000
# 66814              0.25               0         0             -0.008900
# 65534              0.00               0         0             -0.000000
# 41606              0.00               0         0             -0.126337
# 34615              0.00               0         0             -0.057328
# 99535              0.00               0         0             -0.000000
# 42883              0.00               0         0             -0.052080
# 1369               0.00               0         0              3.311646
# 103568             0.00               0         0             -0.000000
# 70579              0.00               0         0             -0.078327
# 42555              0.00               0         0             -0.000304
# 61383              0.00               0         0             -0.001116
# 61054              0.00               0         0             -0.000297
# 102545             0.00               0         0             -0.773164
# 98176              0.00               0         0             -0.443097
# 106181             0.00               0         0             -0.000000
# 112603             0.00               0         0             -0.000000
# 103949             0.00               0         0             -0.467942
# 110302             0.00               0         0             -0.260289
# 58769              0.00               0         0             -0.000000
#
#         withdrawal_over_balance
# 71147                 -0.000715
# 66814                  0.000000
# 65534                 -0.299992
# 41606                  0.000000
# 34615                  0.000000
# 99535                 -0.000064
# 42883                  0.000000
# 1369                   0.000000
# 103568                -0.000746
# 70579                  0.000000
# 42555                  0.000000
# 61383                  0.000000
# 61054                  0.000000
# 102545                 0.000000
# 98176                  0.000000
# 106181                -0.000304
# 112603                -0.165038
# 103949                 0.000000
# 110302                 0.000000
# 58769                 -0.955797

# %% [markdown]
# ### viii. balance_amt

# %%
info , val = first_look(bank, bank.columns[7])

# %%
info
# Out:
#              Column_Name  Null_Rows Column_Type
# column_info  balance_amt          0     float64

# %%
bank.balance_amt.describe()
# Out:
# count    1.162010e+05
# mean    -1.404852e+09
# std      5.348202e+08
# min     -2.045201e+09
# 25%     -1.690383e+09
# 50%     -1.661395e+09
# 75%     -1.236888e+09
# max      8.500000e+06
# Name: balance_amt, dtype: float64

# %%
bank[bank.balance_amt.isna()].count()
# Out:
# account_no                 0
# date                       0
# details                    0
# chq_no                     0
# value_date                 0
# withdrawal_amt             0
# deposit_amt                0
# balance_amt                0
# .                          0
# details_penalty            0
# cheque_penalty             0
# day_diff                   0
# deposit_over_balance       0
# withdrawal_over_balance    0
# dtype: int64

# %% [markdown]
# ### iX. Dropping Empty Column

# %%
info , val = first_look(bank, bank.columns[8])

# %%
info
# Out:
#             Column_Name  Null_Rows Column_Type
# column_info           .          0      object

# %%
val
# Out:
#         .  percent
# .  116201    100.0

# %%
bank.drop(columns=['.'], inplace=True, axis=1)
